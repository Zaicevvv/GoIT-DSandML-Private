# %% [markdown]
# <a href="https://colab.research.google.com/github/Zaicevvv/GoIT-DSandML-Private/blob/main/HW5_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('/content/bestsellers with categories.csv')
data
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %% [markdown]
# Виведіть перші п'ять рядків (використовується функція head)

# %%
data.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %% [markdown]
# Виведіть розміри датасету (використовуйте атрибут shape)

# %%
data.shape
# Out:
# (550, 7)

# %% [markdown]
# Про скільки книг зберігає дані датасет?
# **Відповідь**: 550

# %%
data.columns = ['name', 'author', 'user_rating', 'reviews', 'price', 'year', 'genre']
data
# Out:
#                                                   name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        author  user_rating  reviews  price  year        genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %% [markdown]
# **Первинне дослідження даних**

# %% [markdown]
# Перевірте, чи у всіх рядків вистачає даних: виведіть кількість пропусків (na) у кожному зі стовпців (використовуйте функції isna та sum)

# %%
data.isna().sum()
# Out:
# name           0
# author         0
# user_rating    0
# reviews        0
# price          0
# year           0
# genre          0
# dtype: int64

# %% [markdown]
# Чи є в якихось змінних пропуски? (Так / ні)
# **Відповідь**: ні

# %% [markdown]
# Перевірте, які є унікальні значення в колонці genre (використовуйте функцію unique)

# %%
data['genre'].unique()
# Out:
# array(['Non Fiction', 'Fiction'], dtype=object)

# %% [markdown]
# Які є унікальні жанри?
# **Відповідь**: Non Fiction, Fiction

# %% [markdown]
# Тепер подивіться на розподіл цін: побудуйте діаграму (використовуйте kind='hist')

# %%
import seaborn as sns

plt.grid()
sns.histplot(x='price', data=data, kde=True)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %% [markdown]
# Визначте, яка ціна у нас максимальна, мінімальна, середня, медіанна (використовуйте функції max, min, mean, median)

# %%
max = data['price'].max()
min = data['price'].min()
mean = data['price'].mean()
median = data['price'].median()
print('max:', max, ' min:', min, ' mean:', mean, ' median:', median)
# Out:
# max: 105  min: 0  mean: 13.1  median: 11.0

# %% [markdown]
# Максимальна ціна?
# **Відповідь**: 105
# Мінімальна ціна?
# **Відповідь**: 0
# Середня ціна?
# **Відповідь**: 13.1
# Медіанна ціна?
# **Відповідь**: 11.0

# %% [markdown]
# **Пошук та сортування даних**

# %%
#1
print('1: ', data['user_rating'].max())
#2
print('2: ', data[data['user_rating'] == data['user_rating'].max()]['name'].count())
#3
print('3: ', data[data['reviews'] == data['reviews'].max()].iloc[0, 0])
#4
top_50_books_of_year_2015 = data[data['year'] == 2015].sort_values('user_rating', ascending=False)[:50]
print('4: ', top_50_books_of_year_2015[top_50_books_of_year_2015['price'] == top_50_books_of_year_2015['price'].max()].iloc[0, 0])
#5
print('5: ', data[(data['year'] == 2010) & (data['genre'] == 'Fiction')]['name'].count())
#6
print('6: ', data[((data['year'] == 2010) | (data['year'] == 2011)) & (data['user_rating'] == 4.9)]['name'].count())
# Out:
# 1:  4.9
# 2:  52
# 3:  Where the Crawdads Sing
# 4:  Publication Manual of the American Psychological Association, 6th Edition
# 5:  20
# 6:  1

# %% [markdown]
# Який рейтинг у датасеті найвищий?
# **Відповідь**: 4.9

# %% [markdown]
# Скільки книг мають такий рейтинг?
# **Відповідь**: 52

# %% [markdown]
# Яка книга має найбільше відгуків?
# **Відповідь**: Where the Crawdads Sing

# %% [markdown]
# З тих книг, що потрапили до Топ-50 у 2015 році, яка книга найдорожча (можна використати проміжний датафрейм)?
# **Відповідь**: Publication Manual of the American Psychological Association, 6th Edition

# %% [markdown]
# Скільки книг жанру Fiction потрапили до Топ-50 у 2010 році (використовуйте &)?
# **Відповідь**: 20

# %% [markdown]
# Скільки книг з рейтингом 4.9 потрапило до рейтингу у 2010 та 2011 роках (використовуйте | або функцію isin)?
# **Відповідь**: 1

# %% [markdown]
# І насамкінець, давайте відсортуємо за зростанням ціни всі книги, які потрапили до рейтингу в 2015 році і коштують дешевше за 8 доларів (використовуйте функцію sort_values).

# %%
books = data[(data['year'] == 2015) & (data['price'] < 8)].sort_values('price')
print(books.iloc[len(books)-1, 0])
books
# Out:
# Old School (Diary of a Wimpy Kid #10)
#                                                   name              author  \
# 507                              To Kill a Mockingbird          Harper Lee
# 210                      Laugh-Out-Loud Jokes for Kids         Rob Elliott
# 206                         Knock-Knock Jokes for Kids         Rob Elliott
# 111                                    First 100 Words        Roger Priddy
# 123                               Giraffes Can't Dance       Giles Andreae
# 54   Creative Haven Creative Cats Coloring Book (Ad...     Marjorie Sarnat
# 63                      Dear Zoo: A Lift-the-Flap Book        Rod Campbell
# 89   Dover Creative Haven Art Nouveau Animal Design...         Marty Noble
# 478                        The Very Hungry Caterpillar          Eric Carle
# 201  Killing Reagan: The Violent Assault That Chang...       Bill O'Reilly
# 28                        Baby Touch and Feel: Animals                  DK
# ...

# %% [markdown]
# Яка книга остання у відсортованому списку?
# **Відповідь**: Old School (Diary of a Wimpy Kid #10)

# %% [markdown]
# **Агрегування даних та з'єднання таблиць**

# %% [markdown]
# Для початку давайте подивимося на максимальну та мінімальну ціни для кожного з жанрів (використовуйте функції groupby та agg, для підрахунку мінімальних та максимальних значень використовуйте max та min). Не беріть усі стовпці, виберіть тільки потрібні вам

# %%
data.groupby('genre').agg({'price': ['min', 'max']})
# Out:
#             price
#               min  max
# genre
# Fiction         0   82
# Non Fiction     0  105

# %% [markdown]
# Максимальна ціна для жанру Fiction?
# **Відповідь**: 82

# %% [markdown]
# Мінімальна ціна для жанру Fiction?
# **Відповідь**: 0

# %% [markdown]
# Максимальна ціна для жанру Non Fiction?
# **Відповідь**: 105

# %% [markdown]
# Мінімальна ціна для жанру Non Fiction?
# **Відповідь**: 0

# %% [markdown]
# Тепер створіть новий датафрейм, який вміщатиме кількість книг для кожного з авторів (використовуйте функції groupby та agg, для підрахунку кількості використовуйте count). Не беріть усі стовпці, виберете тільки потрібні

# %%
authors_books_count = data.groupby('author').agg({'name': 'count'})
print(authors_books_count.shape)
print(authors_books_count['name'].idxmax())
print(authors_books_count.loc[authors_books_count['name'].idxmax(), 'name'])
authors_books_count
# Out:
# (248, 1)
# Jeff Kinney
# 12
#                             name
# author
# Abraham Verghese               2
# Adam Gasiewski                 1
# Adam Mansbach                  1
# Adir Levy                      1
# Admiral William H. McRaven     1
# ...                          ...
# Walter Isaacson                3
# William Davis                  2
# William P. Young               2
# Wizards RPG Team               3
# Zhi Gang Sha                   2
#
# [248 rows x 1 columns]

# %% [markdown]
# Якої розмірності вийшла таблиця?
# **Відповідь**: (248, 1)

# %% [markdown]
# Який автор має найбільше книг?
# **Відповідь**: Jeff Kinney

# %% [markdown]
# Скільки книг цього автора?
# **Відповідь**: 12

# %% [markdown]
# Тепер створіть другий датафрейм, який буде вміщати середній рейтинг для кожного автора (використовуйте функції groupby та agg, для підрахунку середнього значення використовуйте mean). Не беріть усі стовпці, виберете тільки потрібні

# %%
authors_avg_rating = data.groupby('author').agg({'user_rating': 'mean'})
print(authors_avg_rating['user_rating'].idxmin())
print(authors_avg_rating.loc[authors_avg_rating['user_rating'].idxmin(), 'user_rating'])
authors_avg_rating
# Out:
# Donna Tartt
# 3.9
#                             user_rating
# author
# Abraham Verghese               4.600000
# Adam Gasiewski                 4.400000
# Adam Mansbach                  4.800000
# Adir Levy                      4.800000
# Admiral William H. McRaven     4.700000
# ...                                 ...
# Walter Isaacson                4.566667
# William Davis                  4.400000
# William P. Young               4.600000
# Wizards RPG Team               4.800000
# Zhi Gang Sha                   4.600000
#
# [248 rows x 1 columns]

# %% [markdown]
# У якого автора середній рейтинг мінімальний?
# **Відповідь**: Donna Tartt

# %% [markdown]
# Який у цього автора середній рейтинг?
# **Відповідь**: 3.9

# %% [markdown]
# З'єднайте останні два датафрейми так, щоб для кожного автора було видно кількість книг та середній рейтинг (Використовуйте функцію concat з параметром axis=1). Збережіть результат у змінну

# %%
authors_books_count_and_avg_rating = pd.concat([authors_books_count, authors_avg_rating], axis=1)
authors_books_count_and_avg_rating
# Out:
#                             name  user_rating
# author
# Abraham Verghese               2     4.600000
# Adam Gasiewski                 1     4.400000
# Adam Mansbach                  1     4.800000
# Adir Levy                      1     4.800000
# Admiral William H. McRaven     1     4.700000
# ...                          ...          ...
# Walter Isaacson                3     4.566667
# William Davis                  2     4.400000
# William P. Young               2     4.600000
# Wizards RPG Team               3     4.800000
# Zhi Gang Sha                   2     4.600000
#
# [248 rows x 2 columns]

# %% [markdown]
# Відсортуйте датафрейм за зростаючою кількістю книг та зростаючим рейтингом (використовуйте функцію sort_values)

# %%
print(authors_books_count_and_avg_rating.sort_values(['name', 'user_rating']).index[0])
authors_books_count_and_avg_rating.sort_values(['name', 'user_rating'])
# Out:
# Muriel Barbery
#                                     name  user_rating
# author
# Muriel Barbery                         1     4.000000
# Chris Cleave                           1     4.100000
# Ian K. Smith M.D.                      1     4.100000
# Pierre Dukan                           1     4.100000
# Elizabeth Strout                       1     4.200000
# ...                                  ...          ...
# American Psychological Association    10     4.500000
# Suzanne Collins                       11     4.663636
# Gary Chapman                          11     4.736364
# Rick Riordan                          11     4.772727
# Jeff Kinney                           12     4.800000
#
# [248 rows x 2 columns]

# %% [markdown]
# Який автор перший у списку?
# **Відповідь**: Muriel Barbery

# %% [markdown]
# Візуалізація

# %%
sns.lmplot(x='user_rating', y='name', data=authors_books_count_and_avg_rating)
